# %% [markdown]
# # TASK 2 Iris_Data_Exploration

# %%
# Importing required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_iris

# %%
# Loading the Iris dataset

iris = load_iris()
df = pd.DataFrame(
    iris.data,
    columns=iris.feature_names
)
df['species'] = iris.target

# %%
# Replacing numerc values with flower names

df['species'] = df['species'].map({
    0: 'Setosa',
    1: 'Versicolor',
    2: 'Virginica'
})

# %%
# Displaying first 5 rows of the dataset

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  Setosa
# 1  Setosa
# 2  Setosa
# 3  Setosa
# 4  Setosa

# %%
# Checking dataset information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# Checking shape of dataset

df.shape
# Out:
# (150, 5)

# %%
# Generating statistical summary

df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
# Checking for missing values

df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# species              0
# dtype: int64

# %%
# Creating pairplot visualization

sns.pairplot(df, hue='species')
plt.show()

# %%
# Creating histograms

df.hist(figsize=(10,8))
plt.show()

# %%
# Creating boxplot

plt.figure(figsize=(10,6))
sns.boxplot(data=df)
plt.show()

# %%
# Creating correlation heatmap

plt.figure(figsize=(8,6))

sns.heatmap(
    df.drop('species', axis=1).corr(),
    annot=True
)
plt.show()

# %% [markdown]
# Conclusion:
#
# The Iris dataset was successfully explored and visualized using Python libraries.
#
# No missing values were found in the dataset. Different visualization techniques such as pairplot, histogram, boxplot, and heatmap helped in understanding the relationships between the features.
#
# This project improved understanding of data analysis and visualization techniques.
